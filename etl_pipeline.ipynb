# %%
import pandas as pd

def extract():
    df = pd.read_csv("data/users.csv")
    return df

extracted = extract()

# %%
def transform(df):
    #drops row where age is missing
    df = df.dropna(subset=["age"])

    #converts age to integer
    df['age'] = df['age'].astype(int)

    #create email_provider
    df['email_provider'] = df['email'].apply(lambda x: x.split('@')[1].strip())

    df["city"] = df['city'].fillna('Unknown')
    df['name'] = df['email'].apply(lambda x: x.split('@')[0])

    return df

transformed = transform(extracted)
# Out:
# /tmp/ipykernel_430234/1432077997.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df['age'].astype(int)
# /tmp/ipykernel_430234/1432077997.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['email_provider'] = df['email'].apply(lambda x: x.split('@')[1].strip())
# /tmp/ipykernel_430234/1432077997.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["city"] = df['city'].fillna('Unknown')
# /tmp/ipykernel_430234/1432077997.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'] = df['email'].apply(lambda x: x.split('@')[0])

# %%
def load(df):
    df.to_csv('cleaned_data.csv', index=False)

load(transformed)
